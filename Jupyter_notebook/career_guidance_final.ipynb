# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\joelf\Downloads\mldata.csv")
df.head()
# Out:
#    Logical_quotient_rating  hackathons  coding_skills_rating  \
# 0                        5           0                     6
# 1                        7           6                     4
# 2                        2           3                     9
# 3                        2           6                     3
# 4                        2           0                     3
#
#    public_speaking_points self_learning_capability Extra_courses_did  \
# 0                       2                      yes                no
# 1                       3                       no               yes
# 2                       1                       no               yes
# 3                       5                       no               yes
# 4                       4                      yes                no
#
#          certifications          workshops reading_and_writing_skills  \
# 0  information security            testing                       poor
# ...

# %%
df['Suggested_Job_Role'].value_counts()
# Out:
# Suggested_Job_Role
# Network Security Engineer                  630
# Software Engineer                          590
# UX Designer                                589
# Software Developer                         587
# Database Developer                         581
# Software Quality Assurance (QA) Testing    571
# Web Developer                              570
# CRM Technical Developer                    567
# Technical Support                          565
# Systems Security Administrator             562
# Applications Developer                     551
# Mobile Applications Developer              538
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (6901, 20)

# %%
df['Interested_Type_of_Books'].value_counts()
# Out:
# Interested_Type_of_Books
# Guide                    405
# Health                   401
# Self help                377
# Horror                   377
# Biographies              219
# Science fiction          218
# Satire                   212
# Childrens                212
# Autobiographies          210
# Prayer books             207
# Fantasy                  205
# Journals                 203
# Trilogy                  203
# Anthology                202
# Encyclopedias            201
# Drama                    201
# Mystery                  200
# History                  199
# Science                  198
# Dictionaries             198
# Diaries                  197
# Religion-Spirituality    197
# Action and Adventure     193
# Poetry                   193
# Cookbooks                186
# Comics                   186
# Art                      186
# Travel                   186
# Series                   180
# Math                     176
# Romance                  173
# ...

# %%
df.isnull().sum()
# Out:
# Logical_quotient_rating                0
# hackathons                             0
# coding_skills_rating                   0
# public_speaking_points                 0
# self_learning_capability               0
# Extra_courses_did                      0
# certifications                         0
# workshops                              0
# reading_and_writing_skills             0
# memory_capability_score                0
# Interested_subjects                    0
# interested_career_area                 0
# Type_of_company_want_to_settle         0
# Taken_inputs_from_seniors_or_elders    0
# Interested_Type_of_Books               0
# Management_or_Technical                0
# hard_or_smart_worker                   0
# worked_in_teams_ever                   0
# Introvert                              0
# Suggested_Job_Role                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6901 entries, 0 to 6900
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Logical_quotient_rating              6901 non-null   int64
#  1   hackathons                           6901 non-null   int64
#  2   coding_skills_rating                 6901 non-null   int64
#  3   public_speaking_points               6901 non-null   int64
#  4   self_learning_capability             6901 non-null   object
#  5   Extra_courses_did                    6901 non-null   object
#  6   certifications                       6901 non-null   object
#  7   workshops                            6901 non-null   object
#  8   reading_and_writing_skills           6901 non-null   object
#  9   memory_capability_score              6901 non-null   object
#  10  Interested_subjects                  6901 non-null   object
# ...

# %%
df.head()
# Out:
#    Logical_quotient_rating  hackathons  coding_skills_rating  \
# 0                        5           0                     6
# 1                        7           6                     4
# 2                        2           3                     9
# 3                        2           6                     3
# 4                        2           0                     3
#
#    public_speaking_points self_learning_capability Extra_courses_did  \
# 0                       2                      yes                no
# 1                       3                       no               yes
# 2                       1                       no               yes
# 3                       5                       no               yes
# 4                       4                      yes                no
#
#          certifications          workshops reading_and_writing_skills  \
# 0  information security            testing                       poor
# ...

# %%
X = df.drop('Suggested_Job_Role', axis=1)
y= df['Suggested_Job_Role']

# %%
X.shape
# Out:
# (6901, 19)

# %%
y
# Out:
# 0       Applications Developer
# 1       Applications Developer
# 2       Applications Developer
# 3       Applications Developer
# 4       Applications Developer
#                  ...
# 6896             Web Developer
# 6897             Web Developer
# 6898             Web Developer
# 6899             Web Developer
# 6900             Web Developer
# Name: Suggested_Job_Role, Length: 6901, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0, shuffle=True)

# %%
df.columns
# Out:
# Index(['Logical_quotient_rating', 'hackathons', 'coding_skills_rating',
#        'public_speaking_points', 'self_learning_capability',
#        'Extra_courses_did', 'certifications', 'workshops',
#        'reading_and_writing_skills', 'memory_capability_score',
#        'Interested_subjects', 'interested_career_area',
#        'Type_of_company_want_to_settle', 'Taken_inputs_from_seniors_or_elders',
#        'Interested_Type_of_Books', 'Management_or_Technical',
#        'hard_or_smart_worker', 'worked_in_teams_ever', 'Introvert',
#        'Suggested_Job_Role'],
#       dtype='object')

# %%
numerical_features = [
    'Logical_quotient_rating',
    'hackathons',
    'coding_skills_rating',
    'public_speaking_points'
]

# %%
categorical_features = [
    'self_learning_capability',
    'Extra_courses_did',
    'certifications',
    'workshops',
    'Interested_subjects',
    'interested_career_area',
    'Type_of_company_want_to_settle',
    'Taken_inputs_from_seniors_or_elders',
    'Interested_Type_of_Books',
    'Management_or_Technical',
    'hard_or_smart_worker',
    'worked_in_teams_ever',
    'Introvert'
]

# %%
ordinal_features = ['reading_and_writing_skills', 'memory_capability_score']

# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
# Define the preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('StandardScale', StandardScaler(), numerical_features),  # Numerical features
        ('OHE', OneHotEncoder(sparse_output=False), categorical_features),  # Nominal categorical features
        ('Ordinal', OrdinalEncoder(), ordinal_features)  # Ordinal categorical features
    ],
    remainder='passthrough'  # Keep the remaining columns as is
)

# %%
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# %%
X_train_transformed
# Out:
# array([[ 1.55004451, -0.9948766 , -1.17173572, ...,  0.        ,
#          2.        ,  2.        ],
#        [ 1.16107121,  0.4974383 ,  1.55901628, ...,  1.        ,
#          2.        ,  1.        ],
#        [-0.00584869, -0.4974383 ,  0.388694  , ...,  1.        ,
#          2.        ,  1.        ],
#        ...,
#        [ 0.38312461, -0.9948766 ,  0.388694  , ...,  0.        ,
#          0.        ,  2.        ],
#        [-1.56174189, -0.4974383 ,  0.388694  , ...,  1.        ,
#          0.        ,  1.        ],
#        [ 1.16107121,  0.9948766 , -1.17173572, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Fit the model
dt_classifier.fit(X_train_transformed, y_train)

# Predict on the testing set
y_pred_dt_classifier = dt_classifier.predict(X_test_transformed)

# Evaluate the model
accuracy_dt_classifier = accuracy_score(y_test, y_pred_dt_classifier)
classification_report_dt_classifier = classification_report(y_test, y_pred_dt_classifier)

# Print evaluation metrics
print(f"Decision Tree Classifier Model Metrics:")
print(f"Accuracy: {accuracy_dt_classifier*100}")
print(f"Classification Report:\n{classification_report_dt_classifier}")
# Out:
# Decision Tree Classifier Model Metrics:
# Accuracy: 8.182476466328747
# Classification Report:
#                                          precision    recall  f1-score   support
#
#                  Applications Developer       0.11      0.11      0.11       120
#                 CRM Technical Developer       0.07      0.11      0.09        92
#                      Database Developer       0.08      0.10      0.09       111
#           Mobile Applications Developer       0.08      0.08      0.08       117
#               Network Security Engineer       0.09      0.09      0.09       122
#                      Software Developer       0.11      0.10      0.10       120
#                       Software Engineer       0.09      0.07      0.08       138
# Software Quality Assurance (QA) Testing       0.07      0.08      0.08       107
#          Systems Security Administrator       0.08      0.06      0.07       116
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Initialize Logistic Regression model
logreg_model = LogisticRegression(random_state=42)

# Fit the model
logreg_model.fit(X_train_transformed, y_train)

# Predict on the testing set
y_pred_logreg = logreg_model.predict(X_test_transformed)

# Evaluate the model
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
classification_report_logreg = classification_report(y_test, y_pred_logreg)

# Print evaluation metrics
print("Logistic Regression Model Metrics:")
print(f"Accuracy: {accuracy_logreg}")
print(f"Classification Report:\n{classification_report_logreg}")
# Out:
# Logistic Regression Model Metrics:
# Accuracy: 0.08544532947139753
# Classification Report:
#                                          precision    recall  f1-score   support
#
#                  Applications Developer       0.14      0.07      0.10       120
#                 CRM Technical Developer       0.04      0.04      0.04        92
#                      Database Developer       0.09      0.12      0.10       111
#           Mobile Applications Developer       0.09      0.08      0.08       117
#               Network Security Engineer       0.08      0.11      0.09       122
#                      Software Developer       0.10      0.10      0.10       120
#                       Software Engineer       0.07      0.04      0.05       138
# Software Quality Assurance (QA) Testing       0.11      0.13      0.12       107
#          Systems Security Administrator       0.08      0.07      0.07       116
# ...

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Initialize SVM classifier
svm_classifier = SVC(kernel='linear', random_state=42)  # You can choose different kernels like 'rbf', 'poly', etc.

# Fit the model
svm_classifier.fit(X_train_transformed, y_train)

# Predict on the testing set
y_pred_svm = svm_classifier.predict(X_test_transformed)

# Evaluate the model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
classification_report_svm = classification_report(y_test, y_pred_svm)

# Print evaluation metrics
print("Support Vector Machine Classifier Model Metrics:")
print(f"Accuracy: {accuracy_svm}")
print(f"Classification Report:\n{classification_report_svm}")
# Out:
# Support Vector Machine Classifier Model Metrics:
# Accuracy: 0.0782041998551774
# Classification Report:
#                                          precision    recall  f1-score   support
#
#                  Applications Developer       0.12      0.09      0.10       120
#                 CRM Technical Developer       0.04      0.07      0.05        92
#                      Database Developer       0.08      0.08      0.08       111
#           Mobile Applications Developer       0.10      0.07      0.08       117
#               Network Security Engineer       0.09      0.11      0.09       122
#                      Software Developer       0.07      0.08      0.08       120
#                       Software Engineer       0.11      0.07      0.08       138
# Software Quality Assurance (QA) Testing       0.10      0.14      0.12       107
#          Systems Security Administrator       0.05      0.04      0.05       116
# ...

# %%
X.columns
# Out:
# Index(['Logical_quotient_rating', 'hackathons', 'coding_skills_rating',
#        'public_speaking_points', 'self_learning_capability',
#        'Extra_courses_did', 'certifications', 'workshops',
#        'reading_and_writing_skills', 'memory_capability_score',
#        'Interested_subjects', 'interested_career_area',
#        'Type_of_company_want_to_settle', 'Taken_inputs_from_seniors_or_elders',
#        'Interested_Type_of_Books', 'Management_or_Technical',
#        'hard_or_smart_worker', 'worked_in_teams_ever', 'Introvert'],
#       dtype='object')

# %%
df.head()
# Out:
#    Logical_quotient_rating  hackathons  coding_skills_rating  \
# 0                        5           0                     6
# 1                        7           6                     4
# 2                        2           3                     9
# 3                        2           6                     3
# 4                        2           0                     3
#
#    public_speaking_points self_learning_capability Extra_courses_did  \
# 0                       2                      yes                no
# 1                       3                       no               yes
# 2                       1                       no               yes
# 3                       5                       no               yes
# 4                       4                      yes                no
#
#          certifications          workshops reading_and_writing_skills  \
# 0  information security            testing                       poor
# ...

# %%
def prediction(input_data):
    # Convert input data to DataFrame
    input_df = pd.DataFrame([input_data])
    
    # Ensure the order of columns matches the preprocessor's expectations
    input_df = input_df[numerical_features + ordinal_features+ categorical_features]
    
    # Transform the features
    transformed_features = preprocessor.transform(input_df)
    
    # Predict using the trained model
    predicted = svm_classifier.predict(transformed_features)
    return predicted[0]

# Provide the values for prediction
input_data = {
    "Logical_quotient_rating": 10,
    "hackathons": 10,
    "coding_skills_rating": 10,
    "public_speaking_points": 10,
    "self_learning_capability": "no",
    "Extra_courses_did": "no",
    "certifications" : "information security",
    "workshops" : "testing",
    "reading_and_writing_skills": "excellent",
    "memory_capability_score": "poor",
    "Interested_subjects": "Management",
    "interested_career_area": "system developer",
    "Type_of_company_want_to_settle" : "BPA",
    "Taken_inputs_from_seniors_or_elders" : "no",
    "Management_or_Technical": "Management",
    "Interested_Type_of_Books": "Series",
    "hard_or_smart_worker": "smart worker",
    "worked_in_teams_ever": "no",
    "Introvert": "yes"
}

# Call the prediction function
result = prediction(input_data)

print("Predicted Job Role:", result)
# Out:
# Predicted Job Role: Technical Support

# %%
import numpy as np
import pandas as pd

def prediction(Logical_quotient_rating, hackathons, coding_skills_rating, public_speaking_points, self_learning_capability, Extra_courses_did, certifications, workshops, reading_and_writing_skills, memory_capability_score, Interested_subjects, interested_career_area, Type_of_company_want_to_settle, Taken_inputs_from_seniors_or_elders, Management_or_Technical, Interested_Type_of_Books, hard_or_smart_worker, worked_in_teams_ever, Introvert):
    # Define the column names based on your DataFrame
    column_names = ['Logical_quotient_rating', 'hackathons', 'coding_skills_rating', 'public_speaking_points', 'self_learning_capability', 'Extra_courses_did', 'certifications', 'workshops', 'reading_and_writing_skills', 'memory_capability_score', 'Interested_subjects', 'interested_career_area', 'Type_of_company_want_to_settle', 'Taken_inputs_from_seniors_or_elders', 'Management_or_Technical', 'Interested_Type_of_Books', 'hard_or_smart_worker', 'worked_in_teams_ever', 'Introvert']
    
    # Create a DataFrame from the input features
    features = pd.DataFrame([[Logical_quotient_rating, hackathons, coding_skills_rating, public_speaking_points, self_learning_capability, Extra_courses_did, certifications, workshops, reading_and_writing_skills, memory_capability_score, Interested_subjects, interested_career_area, Type_of_company_want_to_settle, Taken_inputs_from_seniors_or_elders, Management_or_Technical, Interested_Type_of_Books, hard_or_smart_worker, worked_in_teams_ever, Introvert]], columns=column_names)
    
    # Transform the features
    transformed_features = preprocessor.transform(features)
    
    # Predict using the SVM classifier
    predicted = svm_classifier.predict(transformed_features)
    
    return predicted[0]

# Example inputs
Logical_quotient_rating = 10
hackathons = 10
coding_skills_rating = 10
public_speaking_points = 10
self_learning_capability = "yes"
Extra_courses_did = "yes"
certifications = "distro making"
workshops = "database security"
reading_and_writing_skills = "excellent"
memory_capability_score = "excellent"
Interested_subjects = "data engineering"
interested_career_area = "testing"
Type_of_company_want_to_settle = "BPA"
Taken_inputs_from_seniors_or_elders = "yes"
Management_or_Technical = "Management"
Interested_Type_of_Books = "Guide"
hard_or_smart_worker = "smart worker"
worked_in_teams_ever = "yes"
Introvert = "no"

# Get the prediction
result = prediction(Logical_quotient_rating, hackathons, coding_skills_rating, public_speaking_points, self_learning_capability, Extra_courses_did, certifications, workshops, reading_and_writing_skills, memory_capability_score, Interested_subjects, interested_career_area, Type_of_company_want_to_settle, Taken_inputs_from_seniors_or_elders, Management_or_Technical, Interested_Type_of_Books, hard_or_smart_worker, worked_in_teams_ever, Introvert)

print(result)
# Out:
# Web Developer

# %%
import pickle
pickle.dump(svm_classifier,open('svm_c1.pkl','wb'))
pickle.dump(preprocessor,open('preprocessor_c1.pkl','wb'))
